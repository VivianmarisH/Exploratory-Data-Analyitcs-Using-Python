# %% [markdown]
# # EXPLORORY DATA ANALYTICS (EDA) OF STERLING E-COMMANCE COMPANY

# %% [markdown]
# # Background
#
# -Sterling E-Commerce is a one-stop online shopping destination for a wide range of high-quality products.
#
# -With other competiting online stores such as Alibaba, and Amazon Sterling's mission is to provide quality and affordability products, Sterling E-commerce is committed to continuous innovation and improvement to meet the evolving needs of our customers.

# %% [markdown]
# # Problem statment
# -Sterling E-commerce is having some challenges extracting meanngful insight from the data gathered of its customers.

# %% [markdown]
# # Aim
# -To make more informed decisions and boost effectiveness. This entials working to understand availble data, in order optimize product offerings, streamline operations, and enhance Sterling’s customer experience.

# %% [markdown]
# # Objective
#
# -To better understand their customers' needs, preferences, and behavior.
# -To identify patterns and trends of customer activities.

# %% [markdown]
# # Data
#
# The data used in this case study is a publicly available dataset from Kaggle, which contains information on various properties in Lagos, including their location, size, number of bedrooms, and price. The dataset contains over 545 records and 13 variables.

# %% [markdown]
# # Methodology
#
# The methodology used in this case study involves the following steps:
#
# Data cleaning and preprocessing: The first step is to clean and preprocess the data, including handling missing values, removing outliers, and transforming variables as necessary.
#
# Exploratory data analysis: Next, we will perform exploratory data analysis to gain insights into the data, such as identifying trends and patterns, and identifying correlations between variables.
#
# Data storytelling:

# %% [markdown]
# IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # DATA LOADING

# %%
df = pd.read_csv(r"C:\Users\oguad\Desktop\10ANALYTICS DATA SCIENCE\VIDEOS\EDA Group Project\Sterling E-Commerce Data.csv")

# %%
df.head()
# Out:
#           Category           City     County  Cust Id Customer Since  \
# 0  Health & Sports           Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 3        Computing  Young America     Carver   112501      9/15/2013
# 4    Entertainment  Young America     Carver   112501      9/15/2013
#
#     Date of Order        Full Name Gender  Item Id     Order Id  \
# 0   8/7/2022 0:00   Renaud, Maudie      F   880913  100547952.0
# 1   8/8/2022 0:00   Shimp, Mariela      F   881493  100548328.0
# 2   8/8/2022 0:00   Shimp, Mariela      F   881492  100548328.0
# 3  8/18/2022 0:00  Doiron, Latrina      F   886067  100551079.0
# 4  8/20/2022 0:00  Doiron, Latrina      F   886878  100551618.0
#
#   Payment Method     Place Name  Ref Num   Region State User Name    Zip  \
# 0     Easypay_MA           Bode   352808  Midwest    IA  mcrenaud  50519
# ...

# %% [markdown]
# # DATA INSPECTION AND CLEANING

# %%
df.columns
# Out:
# Index(['Category', 'City', 'County', 'Cust Id', 'Customer Since',
#        'Date of Order', 'Full Name', 'Gender', 'Item Id', 'Order Id',
#        'Payment Method', 'Place Name', 'Ref Num', 'Region', 'State',
#        'User Name', 'Zip', 'Qty Ordered', 'Total'],
#       dtype='object')

# %%
df.shape
# Out:
# (283083, 19)

# %%
df.describe()
# Out:
#              Cust Id        Item Id      Order Id        Ref Num  \
# count  283083.000000  283083.000000  2.830780e+05  283083.000000
# mean    70106.816026  741747.110628  1.004570e+08  561107.885991
# std     30215.394879   95664.609013  6.090992e+04  256101.205409
# min         4.000000  574769.000000  1.003547e+08  111127.000000
# 25%     56640.000000  659898.500000  1.004047e+08  341071.000000
# 50%     74320.000000  742471.000000  1.004518e+08  565623.000000
# 75%     92371.000000  826078.500000  1.005134e+08  782211.000000
# max    115326.000000  905208.000000  1.005624e+08  999981.000000
#
#                  Zip    Qty Ordered          Total
# count  283083.000000  283083.000000  283083.000000
# mean    49147.171374       3.008224     816.230712
# std     27235.561738       4.565168    1986.164932
# min       210.000000       1.000000       0.000000
# 25%     26264.000000       2.000000      49.900000
# 50%     48808.000000       2.000000     149.800000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283083 entries, 0 to 283082
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Category        283083 non-null  object
#  1   City            283083 non-null  object
#  2   County          283083 non-null  object
#  3   Cust Id         283083 non-null  int64
#  4   Customer Since  283083 non-null  object
#  5   Date of Order   283083 non-null  object
#  6   Full Name       283083 non-null  object
#  7   Gender          283083 non-null  object
#  8   Item Id         283083 non-null  int64
#  9   Order Id        283078 non-null  float64
#  10  Payment Method  283083 non-null  object
#  11  Place Name      283083 non-null  object
#  12  Ref Num         283083 non-null  int64
#  13  Region          283083 non-null  object
#  14  State           283083 non-null  object
#  15  User Name       283083 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# County            0
# Cust Id           0
# Customer Since    0
# Date of Order     0
# Full Name         0
# Gender            0
# Item Id           0
# Order Id          5
# Payment Method    0
# Place Name        0
# Ref Num           0
# Region            0
# State             0
# User Name         0
# Zip               0
# Qty Ordered       0
# Total             0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                  Category          City    County  Cust Id Customer Since  \
# 38758             Soghaat  Leiters Ford    Fulton   111867      11/4/2010
# 38759             Soghaat  Leiters Ford    Fulton   111867      11/4/2010
# 133217  Mobiles & Tablets    Rock Point   Charles    92075       4/8/2014
# 145889  Mobiles & Tablets     Uniopolis  Auglaize   111166      2/23/2017
# 224999          Computing    Barrington    Camden    40853      8/24/2009
#
#          Date of Order            Full Name Gender  Item Id  Order Id  \
# 38758    8/4/2022 0:00          Wright, Man      M   879766       NaN
# 38759    8/4/2022 0:00          Wright, Man      M   879765       NaN
# 133217   4/1/2022 0:00  Torkelson, Berneice      F   767619       NaN
# 145889  7/21/2022 0:00      Cannon, Shamika      F   872703       NaN
# 224999  8/12/2022 0:00    Robichaux, Marion      M   883358       NaN
#
#        Payment Method    Place Name  Ref Num     Region State    User Name  \
# ...

# %%
df=df.fillna('Unknown')

# %%
df[df['Order Id']== 'Unknown']
# Out:
#                  Category          City    County  Cust Id Customer Since  \
# 38758             Soghaat  Leiters Ford    Fulton   111867      11/4/2010
# 38759             Soghaat  Leiters Ford    Fulton   111867      11/4/2010
# 133217  Mobiles & Tablets    Rock Point   Charles    92075       4/8/2014
# 145889  Mobiles & Tablets     Uniopolis  Auglaize   111166      2/23/2017
# 224999          Computing    Barrington    Camden    40853      8/24/2009
#
#          Date of Order            Full Name Gender  Item Id Order Id  \
# 38758    8/4/2022 0:00          Wright, Man      M   879766  Unknown
# 38759    8/4/2022 0:00          Wright, Man      M   879765  Unknown
# 133217   4/1/2022 0:00  Torkelson, Berneice      F   767619  Unknown
# 145889  7/21/2022 0:00      Cannon, Shamika      F   872703  Unknown
# 224999  8/12/2022 0:00    Robichaux, Marion      M   883358  Unknown
#
#        Payment Method    Place Name  Ref Num     Region State    User Name  \
# ...

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# County            0
# Cust Id           0
# Customer Since    0
# Date of Order     0
# Full Name         0
# Gender            0
# Item Id           0
# Order Id          0
# Payment Method    0
# Place Name        0
# Ref Num           0
# Region            0
# State             0
# User Name         0
# Zip               0
# Qty Ordered       0
# Total             0
# dtype: int64

# %%
df.head(5)
# Out:
#           Category           City     County  Cust Id Customer Since  \
# 0  Health & Sports           Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 3        Computing  Young America     Carver   112501      9/15/2013
# 4    Entertainment  Young America     Carver   112501      9/15/2013
#
#     Date of Order        Full Name Gender  Item Id     Order Id  \
# 0   8/7/2022 0:00   Renaud, Maudie      F   880913  100547952.0
# 1   8/8/2022 0:00   Shimp, Mariela      F   881493  100548328.0
# 2   8/8/2022 0:00   Shimp, Mariela      F   881492  100548328.0
# 3  8/18/2022 0:00  Doiron, Latrina      F   886067  100551079.0
# 4  8/20/2022 0:00  Doiron, Latrina      F   886878  100551618.0
#
#   Payment Method     Place Name  Ref Num   Region State User Name    Zip  \
# 0     Easypay_MA           Bode   352808  Midwest    IA  mcrenaud  50519
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Aalytics

# %%
df["Unit_Price"] = round(df["Total"] / df["Qty Ordered"], 2)
df.head()
# Out:
#           Category           City     County  Cust Id Customer Since  \
# 0  Health & Sports           Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 3        Computing  Young America     Carver   112501      9/15/2013
# 4    Entertainment  Young America     Carver   112501      9/15/2013
#
#     Date of Order        Full Name Gender  Item Id     Order Id  \
# 0   8/7/2022 0:00   Renaud, Maudie      F   880913  100547952.0
# 1   8/8/2022 0:00   Shimp, Mariela      F   881493  100548328.0
# 2   8/8/2022 0:00   Shimp, Mariela      F   881492  100548328.0
# 3  8/18/2022 0:00  Doiron, Latrina      F   886067  100551079.0
# 4  8/20/2022 0:00  Doiron, Latrina      F   886878  100551618.0
#
#   Payment Method     Place Name  Ref Num   Region State User Name    Zip  \
# 0     Easypay_MA           Bode   352808  Midwest    IA  mcrenaud  50519
# ...

# %%
df = df.rename(columns={'Total': 'Revenue'})
df.head()
# Out:
#           Category           City     County  Cust Id Customer Since  \
# 0  Health & Sports           Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 3        Computing  Young America     Carver   112501      9/15/2013
# 4    Entertainment  Young America     Carver   112501      9/15/2013
#
#     Date of Order        Full Name Gender  Item Id     Order Id  \
# 0   8/7/2022 0:00   Renaud, Maudie      F   880913  100547952.0
# 1   8/8/2022 0:00   Shimp, Mariela      F   881493  100548328.0
# 2   8/8/2022 0:00   Shimp, Mariela      F   881492  100548328.0
# 3  8/18/2022 0:00  Doiron, Latrina      F   886067  100551079.0
# 4  8/20/2022 0:00  Doiron, Latrina      F   886878  100551618.0
#
#   Payment Method     Place Name  Ref Num   Region State User Name    Zip  \
# 0     Easypay_MA           Bode   352808  Midwest    IA  mcrenaud  50519
# ...

# %%
# Split the 'Full Name' column into 'First Name' and 'Last Name' columns
df[['First Name', 'Last Name']] = df['Full Name'].str.split(' ', n=1, expand=True)

plt.show()

# %%
#Extrat the month, quater and Year from Date_of_Order column
df['Date of Order'] = pd.to_datetime(df['Date of Order'])

#df["month"] = df["Date_of_Order"].dt.month
df['year'] = df['Date of Order'].dt.year
df['month'] = df['Date of Order'].dt.month
df['month_name'] = df['Date of Order'].dt.month_name()
df['quarter'] = df['Date of Order'].dt.quarter

df.head(3)
# Out:
#           Category        City     County  Cust Id Customer Since  \
# 0  Health & Sports        Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion  Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion  Belleville  St. Clair   112386      6/23/2005
#
#   Date of Order       Full Name Gender  Item Id     Order Id  ...    Zip  \
# 0    2022-08-07  Renaud, Maudie      F   880913  100547952.0  ...  50519
# 1    2022-08-08  Shimp, Mariela      F   881493  100548328.0  ...  62223
# 2    2022-08-08  Shimp, Mariela      F   881492  100548328.0  ...  62223
#
#   Qty Ordered  Revenue Unit_Price First Name Last Name  year  month  \
# 0           3     32.0      10.67    Renaud,    Maudie  2022      8
# 1           2     74.8      37.40     Shimp,   Mariela  2022      8
# 2           2     74.9      37.45     Shimp,   Mariela  2022      8
#
#    month_name  quarter
# 0      August        3
# 1      August        3
# 2      August        3
#
# [3 rows x 26 columns]

# %%
# Create pivot table with years as columns
pivot_df = pd.pivot_table(df, values='Revenue', index=df.index, columns='year')

# Add the years as columns to the table
years = df['year'].unique()
for year in years:
    pivot_df[f'year_{year}'] = pivot_df[year]
    
# Drop the original year columns
pivot_df.drop(columns=years, inplace=True)
    
# Display the table
print(pivot_df)
# Out:
# year    year_2022  year_2021
# 0            32.0        NaN
# 1            74.8        NaN
# 2            74.9        NaN
# 3          6822.9        NaN
# 4          2849.9        NaN
# ...           ...        ...
# 283078        NaN       69.8
# 283079        NaN       69.9
# 283080        NaN       79.8
# 283081        NaN       79.9
# 283082        NaN       79.9
#
# [283083 rows x 2 columns]

# %%
#Creating a function for percentage calculation and application on plots    
def perc_plot(plot, feature):
    total = len(feature)
    for p in plot.patches:
        perc = '{:.1f}%'.format(100 * p.get_height() / total)  # Fixed formatting issue here
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        plot.annotate(perc, (x, y), ha='center')
    plt.show()

# %%
#Display of category distribution
plt.figure(figsize=(15, 5))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('CATEGORY DISTRIBUTION', fontsize=20)
df["Category"].value_counts().plot(kind="bar")

plt.show()

# %% [markdown]
# COMMENTS:
#
# From the chart above, it is evident that the top three purchased goods are mobiles and tablet, men's fashion and appliances while the least performing product category are Books and School & Education.

# %%
df.groupby("Category")[["Unit_Price"]].median().astype(int).reset_index()
# Out:
#               Category  Unit_Price
# 0           Appliances         157
# 1    Beauty & Grooming          22
# 2                Books           0
# 3            Computing         173
# 4        Entertainment         798
# 5      Health & Sports          19
# 6        Home & Living          18
# 7          Kids & Baby          21
# 8        Men's Fashion          34
# 9    Mobiles & Tablets         583
# 10              Others          80
# 11  School & Education          18
# 12             Soghaat          15
# 13          Superstore          17
# 14     Women's Fashion          59

# %%
#Visual showing the count of category distribution
plt.figure(figsize=(30, 10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=20)
plt.xlabel('category', fontsize=20)
plt.ylabel('count', fontsize=30)
plt.title('COUNT OF CATEGORY DISTRIBUTION', fontsize=35)
ax = sns.countplot(x=df["Category"])

plt.show()

# %% [markdown]
# COMMENTS:
#
# This chart shows the product categories with the highest counts. They are Mobil & Tablets, Men's Fashion and Appliances.

# %%
plt.figure(figsize=(17,10))
ax = sns.countplot(y=df['Payment Method'], order=df['Payment Method'].value_counts(ascending=False).index)
values = df['Payment Method'].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=values);
plt.title('COUNT OF PAYMENT METHOD', fontsize=20)

plt.show()

# %% [markdown]
# COMMENTS:
#
# The COD payment method has been observed as the mostly used by customer with a count of 101,750 as against financesettlement payment method which is the least used with a count of 1.

# %%
fig,ax=plt.subplots(figsize=(10,8))
top_five= df["Payment Method"].value_counts().head(5)
ax.pie(top_five, labels=top_five.index, autopct=lambda p:f'{p:.2f}%')
plt.title('TOP FIVE PAYMENT METHODS', fontsize=20)

plt.show()

# %% [markdown]
# COMMENTS:
#
# This visual display highlights the top 5 payment methods used by customers in percentages. Notice the Payaxis and the easypay_voucher; they have an alomst equal proportion of use by customers. COD is the most popular with percentage value of 40.15 (40.15%).

# %%
fig,ax=plt.subplots(figsize=(10,8))
count = Counter(df["Gender"])
ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f'{p:.2f}%')
ax.set_title("TRANSACTION BY GENDER", fontsize=20)
plt.show();

# %% [markdown]
# COMMENTS:
#
# The male gender make up for the highest transactions even though the transactions made by the female gender is almost the same as the male.

# %%
#Top Ten transactions by State
plt.figure(figsize=(20,7))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('State', fontsize=15)
plt.ylabel('count', fontsize=15)
plt.title('TOP TEN TRANSACTION BY STATE', fontsize=20)

topten= df["State"].value_counts().head(10)
ax = sns.countplot(x="State", data=df, order=topten.index)
perc_plot(ax, df['State'])

plt.show();

# %% [markdown]
# COMMENTS:
#
# Chart of the top ten states with customers making the most transactions. The state of Texas ranks top with a little over 17500 transactions followed by the state of Califolnia.

# %%
#Top Ten transactions by State
plt.figure(figsize=(20,7))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('City', fontsize=15)
plt.ylabel('count', fontsize=15)
plt.title('TOP TEN TRANSACTION BY City', fontsize=20)

topten= df["City"].value_counts().head(10)
ax = sns.countplot(x="City", data=df, order=topten.index);
perc_plot(ax, df['City'])

plt.show();

# %% [markdown]
# COMMENTS:
#
# This barchart of the top ten cities with customers making the most transactions shows that the city of Dekalb ranks top with a little over 2500 transactions followed by Washington city.

# %%
#Extract the year, month and quarter by creating new columns
df['Date of Order']=pd.to_datetime(df['Date of Order'])

df['year'] = df['Date of Order'].dt.year
df['month'] = df['Date of Order'].dt.month
df['month_name'] = df['Date of Order'].dt.month_name()
df['quarter'] = df['Date of Order'].dt.quarter

df.head(2)
# Out:
#           Category        City     County  Cust Id Customer Since  \
# 0  Health & Sports        Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion  Belleville  St. Clair   112386      6/23/2005
#
#   Date of Order       Full Name Gender  Item Id     Order Id  ...    Zip  \
# 0    2022-08-07  Renaud, Maudie      F   880913  100547952.0  ...  50519
# 1    2022-08-08  Shimp, Mariela      F   881493  100548328.0  ...  62223
#
#   Qty Ordered  Revenue Unit_Price First Name Last Name  year  month  \
# 0           3     32.0      10.67    Renaud,    Maudie  2022      8
# 1           2     74.8      37.40     Shimp,   Mariela  2022      8
#
#    month_name  quarter
# 0      August        3
# 1      August        3
#
# [2 rows x 26 columns]

# %%
#Orders by Month name
orders_by_month = df['month_name'].value_counts().reset_index()
orders_by_month.columns = ['month_name', 'Qty Ordered' ]

orders_by_month
# Out:
#    month_name  Qty Ordered
# 0    December        81607
# 1       April        41693
# 2       March        26608
# 3        June        26532
# 4    November        17086
# 5     January        17038
# 6        July        15154
# 7         May        14684
# 8   September        12288
# 9      August        11294
# 10   February         9991
# 11    October         9108

# %%
plt.figure(figsize=(9,5))
plt.xticks(fontsize=12)
plt.yticks(fontsize=10)
plt.xlabel('year', fontsize=20)
plt.ylabel('Qty Ordered', fontsize=20)
plt.title('ORDER BY YEAR', fontsize=22)

topten= df["year"].value_counts().head(10)
ax = sns.countplot(x="year", data=df, order=df['year'].value_counts(ascending=False).index)
values = df['year'].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=values);

plt.show()

# %% [markdown]
# COMMENTS:
#
# Year 2022 shows that there were moore orders made by customers compared to the year 2021.

# %%
plt.figure(figsize=(20,10))
plt.xticks(fontsize=17)
plt.yticks(fontsize=18)
plt.xlabel('Qty Ordered', fontsize=20)
plt.ylabel('month_name', fontsize=20)
plt.title('ORDER BY MONTH', fontsize=30)
ax = sns.countplot(y=df['month_name'], order=df['month_name'].value_counts(ascending=False).index)
values = df['month_name'].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=values);

plt.show();

# %% [markdown]
# NOTE: The highest order/purchase were made in the month of April and December. Most likely due to seasonal celebration (Festive Chritmas, Easter, and Sallah celebration)

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(30,10))
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 19)
plt.xlabel('category', fontsize = 20)
plt.ylabel('Qty Ordered',  fontsize = 20)
plt.title('CATEGORY VS QTY ORDERED', fontsize = 30)
cat_qty= df.groupby("Category")["Qty Ordered"].sum().reset_index()
ax = sns.barplot(x="Category", data=cat_qty, y='Qty Ordered')
perc_plot(ax, df['Category'])

plt.show();

# %% [markdown]
# This table shows the product categories mostly ordered by customers in percentage. The Mobile and Tablets appears to be the largest with 47.1% with Books with 0.8% as the least ordered.

# %%
plt.figure(figsize=(30,40))
topten= df["Category"].value_counts().head(10)
sns.boxplot(x='Category', y='Revenue', data=df, order=topten.index)

plt.show();

# %% [markdown]
# COMMENTS:
#
# Although the Men's fashion, superstore and others product categories were the majority of customer product orders, the boxplot has shown that they do not contribut the majority of revenue to Sterling e-commerce. The Mobile & Tablets, Appliances and surprisingly, Entaitainment categories recorded the highest in revenue generation with MObile & Tablet as the highest.

# %%
plt.figure(figsize=(30,13))
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 20)
plt.xlabel('Payment Method', fontsize = 20)
plt.ylabel('Revenue',  fontsize = 25)
plt.title('REVENUE BY PAYMENT METHODS', fontsize = 28)
full_rev = df.groupby("Payment Method")["Revenue"].sum().reset_index()
ax=sns.barplot(x="Payment Method", data=full_rev, y='Revenue')

# Percentage of quantity ordered 
revenue_percentage = full_rev["Revenue"] / full_rev["Revenue"].sum() * 100

# Add quantity ordered percentage line
for i, p in enumerate(ax.patches):
    ax.annotate(f'{revenue_percentage[i]:.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), textcoords='offset points')

plt.show();

# %% [markdown]
# COMMENTS:
#
# The COD and Payaxis are the most popular payment methods used by customers within the states and in the cities, however, they show little potential in revenue generation. Instead, the Easypay, bankalfalah and easypay_voucher are the top 3 revenue generators with Easypay as the top most with 23.5%.

# %%
plt.figure(figsize=(20,10))
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 20)
plt.xlabel('First Name', fontsize = 20)
plt.ylabel('Revenue',  fontsize = 30)
plt.title('Customer vs Revenue', fontsize = 30)
topten= df["First Name"].value_counts().head(10)
sns.boxplot(x='First Name', y='Revenue', data=df, order=topten.index)

plt.show();

# %% [markdown]
# COMMENTS:
#
# This boxplot showcases the top ten customers putting in a lot of fund into this company. These customers patronise the e-commerce business generating them huge revenue. Beebe takes the lead with Glines as another customer with strong purchasing power followed by Jesse.

# %%
df.head()
# Out:
#           Category           City     County  Cust Id Customer Since  \
# 0  Health & Sports           Bode   Humboldt   112285      2/11/2008
# 1    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 2    Men's Fashion     Belleville  St. Clair   112386      6/23/2005
# 3        Computing  Young America     Carver   112501      9/15/2013
# 4    Entertainment  Young America     Carver   112501      9/15/2013
#
#   Date of Order        Full Name Gender  Item Id     Order Id  ...    Zip  \
# 0    2022-08-07   Renaud, Maudie      F   880913  100547952.0  ...  50519
# 1    2022-08-08   Shimp, Mariela      F   881493  100548328.0  ...  62223
# 2    2022-08-08   Shimp, Mariela      F   881492  100548328.0  ...  62223
# 3    2022-08-18  Doiron, Latrina      F   886067  100551079.0  ...  55552
# 4    2022-08-20  Doiron, Latrina      F   886878  100551618.0  ...  55552
#
#   Qty Ordered  Revenue Unit_Price First Name Last Name  year  month  \
# ...

# %%
plt.figure(figsize=(15, 7))
plt.xticks(fontsize=20)
plt.yticks(fontsize=12)
plt.xlabel('Qty Ordered', fontsize=20)
plt.ylabel('Qty Ordered', fontsize=20)
plt.title('QTY ORDERED BY REGION', fontsize=20)
reg_total = df.groupby("Region")["Qty Ordered"].sum().reset_index()
ax = sns.barplot(y="Qty Ordered", data=reg_total, x='Region')

# Calculate quantity ordered percentage
qty_ordered_percentage = reg_total["Qty Ordered"] / reg_total["Qty Ordered"].sum() * 100

# Add quantity ordered percentage line
for i, p in enumerate(ax.patches):
    ax.annotate(f'{qty_ordered_percentage[i]:.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# COMMENTS:
#
# The South region has presented it self as the region with the highest customer order made.

# %%
# Distribution of furnishing status and price
plt.figure(figsize=(15,7))
plt.xticks(fontsize=15)
plt.yticks(fontsize=20)
plt.xlabel('Revenue', fontsize=20)
plt.ylabel('Region', fontsize=20)
plt.title('REVENUE BY REGION', fontsize=20)
reg_total= df.groupby("Region")["Revenue"].sum().reset_index()
ax=sns.barplot(y="Revenue", data=reg_total, x='Region')

COMMENTS:

# %% [markdown]
# COMMENTS:
#
# The South region has presented it self as the region with the highest highest revenue renerating power.

# %%
plt.figure(figsize=(30,25))
plt.xticks(fontsize=14)
plt.yticks(fontsize=20)
plt.xlabel('category', fontsize=25)
plt.ylabel('Unit_Price',  fontsize=25)
plt.title('Category vs Unit_Price', fontsize=35)
sns.boxplot(x='Category', y='Unit_Price', data=df);

plt.show();

# %% [markdown]
# COMMENTS:
#
# The computing, Entertainmet, and Mobile & Tablets have high Unit_Price. Perhaps this is the reason why they generated more revenue.

# %%
plt.figure(figsize=(20,8))
plt.xticks(fontsize=16)
plt.yticks(fontsize=20)
plt.xlabel('State', fontsize=20)
plt.ylabel('Revenue',  fontsize=20)
plt.title('REVENUE BY STATE', fontsize=30)
county_total= df.groupby("State")["Revenue"].sum().reset_index()
topten= df["State"].value_counts()[:10]
ax=sns.barplot(x="State", data=county_total, y='Revenue', order=topten.index)
COMMENTS:

The South region has presented it self as the region with the highest customer order made.
plt.show();

# %% [markdown]
# COMMENTS:
#
# The top three states in terms of revenue genration are Texas, Califonia and New York.

# %%
plt.figure(figsize=(8,5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=15)
plt.xlabel('Gender', fontsize=20)
plt.ylabel('Revenue',  fontsize=20)
plt.title('REVENUE BY GENDER', fontsize=20)
Rev_gen= df.groupby("Gender")["Revenue"].sum().reset_index()
ax = sns.barplot(x="Gender", data=Rev_gen, y='Revenue')
COMMENTS:

The South region has presented it self as the region with the highest customer order made.
# Calculate quantity ordered percentage
Rev_gen_percentage = Rev_gen["Revenue"] / Rev_gen["Revenue"].sum() * 100

# Add quantity ordered percentage line
for i, p in enumerate(ax.patches):
    ax.annotate(f'{Rev_gen_percentage[i]:.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), textcoords='offset points')

plt.show();

# %% [markdown]
# COMMENTS:
#
# Although from previous observations, the male gender has the most transaction activities, however, the female geneder hold the greater power in terms of revenue.

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
#Compare category, Qty Ordered, revenue and Unit_Price

cat = df.groupby("Category")[["Qty Ordered", "Unit_Price", "Revenue"]].sum().reset_index()
cat

#Lets visualise-In order to do this, we transpose Qty Ordered, revenue and Unit_Price columns into a single column (metriec)
cat1 = pd.melt(cat, id_vars="Category", var_name="Metric", value_name="Total")
cat1
# Out:
#               Category       Metric         Total
# 0           Appliances  Qty Ordered  8.168800e+04
# 1    Beauty & Grooming  Qty Ordered  6.998100e+04
# 2                Books  Qty Ordered  2.131000e+03
# 3            Computing  Qty Ordered  2.029500e+04
# 4        Entertainment  Qty Ordered  3.433000e+04
# 5      Health & Sports  Qty Ordered  2.838800e+04
# 6        Home & Living  Qty Ordered  4.127500e+04
# 7          Kids & Baby  Qty Ordered  2.045400e+04
# 8        Men's Fashion  Qty Ordered  1.012120e+05
# 9    Mobiles & Tablets  Qty Ordered  1.332210e+05
# 10              Others  Qty Ordered  1.085400e+05
# 11  School & Education  Qty Ordered  4.406000e+03
# 12             Soghaat  Qty Ordered  2.803700e+04
# 13          Superstore  Qty Ordered  9.950300e+04
# 14     Women's Fashion  Qty Ordered  7.811600e+04
# 15          Appliances   Unit_Price  1.285956e+07
# 16   Beauty & Grooming   Unit_Price  8.140512e+05
# 17               Books   Unit_Price  1.502551e+04
# ...

# %%
#Lets visualise-In order to do this
plt.figure(figsize=(30,10))
plt.xticks(fontsize=15)
plt.yticks(fontsize=20)
plt.xlabel('Category', fontsize=30)
plt.ylabel('Total',  fontsize=30)
plt.title('CATEGORY EVALUATION', fontsize=30)
cat1 = pd.melt(cat, id_vars="Category", var_name="Metric", value_name="Total")
sns.barplot(x="Category", y="Total", data=cat1, hue="Metric")

plt.show();

# %% [markdown]
# COMMENTS:
#
# Looking across the entire multivariate chart above, it is noted that the revenue genrated by each category is al,ost 100% of the unit price. This is to say that the price for each product category is just right and the revenue generated is just as much as suitable for the business.

# %%
#Compare Payment method, Qty Ordered, revenue, Unit_Price

paym = df.groupby("Payment Method")[["Qty Ordered", "Revenue", "Unit_Price"]].sum().reset_index()
paym

#Lets visualise-In order to do this, we transpose Qty Ordered, revenue and Unit_Price columns into a single column (metriec)
paym1 = pd.melt(paym, id_vars="Payment Method", var_name="Metric", value_name="Total")
paym1
# Out:
#        Payment Method       Metric         Total
# 0             Easypay  Qty Ordered  2.306890e+05
# 1          Easypay_MA  Qty Ordered  3.617600e+04
# 2             Payaxis  Qty Ordered  1.164570e+05
# 3                 apg  Qty Ordered  5.111000e+03
# 4         bankalfalah  Qty Ordered  7.521300e+04
# 5      cashatdoorstep  Qty Ordered  1.900000e+01
# 6                 cod  Qty Ordered  2.734670e+05
# 7      customercredit  Qty Ordered  9.877000e+03
# 8     easypay_voucher  Qty Ordered  6.532600e+04
# 9   financesettlement  Qty Ordered  2.000000e+00
# 10        jazzvoucher  Qty Ordered  1.726900e+04
# 11         jazzwallet  Qty Ordered  2.155000e+04
# 12            mcblite  Qty Ordered  4.210000e+02
# 13            Easypay      Revenue  5.418908e+07
# 14         Easypay_MA      Revenue  6.662707e+06
# 15            Payaxis      Revenue  3.759357e+07
# 16                apg      Revenue  1.360129e+06
# 17        bankalfalah      Revenue  4.723183e+07
# ...

# %%
#Lets visualise-In order to do this
plt.figure(figsize=(20,15))
plt.xticks(fontsize=15)
plt.yticks(fontsize=20)
plt.xlabel('Payment Method', fontsize=30)
plt.ylabel('Total',  fontsize=30)
plt.title('PAMENT METHOD EVALUATION', fontsize=30)
paym1 = pd.melt(paym, id_vars="Payment Method", var_name="Metric", value_name="Total")
sns.barplot(y="Payment Method", x="Total", data=paym1, hue="Metric")

plt.show();

# %% [markdown]
# COMMENTS:
#
# From the bar chart, the quantity orederd by COD is higher that the other payment methods, four payment methods seem to be bringing in more revenue to the business that the COD. Perhaps the COD is mostly used for lower priced items. The Easypay still remains top amongst all.

# %%
#Compare Revenue, month name, Qty Ordered

montn = df.groupby("month_name")[["Qty Ordered", "Revenue"]].sum().reset_index()
montn

#Lets visualise-In order to do this, we transpose Revenue, month_name columns into a single column (metriec)
montn1 = pd.melt(montn, id_vars="month_name", var_name="Metric", value_name="Total")
montn1
# Out:
#    month_name       Metric         Total
# 0       April  Qty Ordered  1.485410e+05
# 1      August  Qty Ordered  3.117500e+04
# 2    December  Qty Ordered  1.830480e+05
# 3    February  Qty Ordered  3.251900e+04
# 4     January  Qty Ordered  4.798100e+04
# 5        July  Qty Ordered  5.794200e+04
# 6        June  Qty Ordered  9.136700e+04
# 7       March  Qty Ordered  1.008580e+05
# 8         May  Qty Ordered  4.778300e+04
# 9    November  Qty Ordered  4.429900e+04
# 10    October  Qty Ordered  2.227300e+04
# 11  September  Qty Ordered  4.379100e+04
# 12      April      Revenue  3.626799e+07
# 13     August      Revenue  2.024601e+07
# 14   December      Revenue  5.697471e+07
# 15   February      Revenue  4.365058e+06
# 16    January      Revenue  7.100697e+06
# 17       July      Revenue  1.878224e+07
# 18       June      Revenue  2.440702e+07
# 19      March      Revenue  2.488916e+07
# 20        May      Revenue  1.000833e+07
# 21   November      Revenue  1.137394e+07
# ...

# %%
#Lets visualise-In order to do this
plt.figure(figsize=(20,10))
plt.xticks(fontsize=15)
plt.yticks(fontsize=20)
plt.xlabel('month_name', fontsize=30)
plt.ylabel('Total',  fontsize=30)
plt.title('MONTH VS REVENUE EVALUATION', fontsize=30)
montn = pd.melt(montn, id_vars="month_name", var_name="Metric", value_name="Total")
sns.barplot(y="month_name", x="Total", data=montn1, hue="Metric");

# %% [markdown]
# -Because of the number difference, quantity is of smaller bar in this chart.
#
# -The months of December and April show highest revenue counts.
#
# -These months also display the highest product order made by customers.
#
# -The high volume of order and huge revenue generated in these months could possibly be attributed to the fact that the months in question are festive months (Christmas and Easter celebration).

# %% [markdown]
# # TREND ANALYSIS

# %%
#Compare Revenue and 3 variable to unerstand trends
plt.figure(figsize=(23, 10))

plt.yticks(fontsize=15)
plt.xlabel('Payment Method', fontsize=20)
plt.ylabel('Revenue',  fontsize=20)
sns.lineplot(x="Payment Method", y="Revenue", data=df, hue='year')
plt.title('PAYMENT METHOD/REVENUE TREND ANALYSIS', fontsize=25)

plt.show();

# %%
#using pivot table 
df.pivot_table(values="Revenue", index="year", columns="Payment Method", aggfunc="sum")
# Out:
# Payment Method       Easypay   Easypay_MA       Payaxis          apg  \
# year
# 2021            2.044683e+07  3452588.433  8.807779e+06          NaN
# 2022            3.374224e+07  3210118.812  2.878579e+07  1360129.261
#
# Payment Method   bankalfalah  cashatdoorstep           cod  customercredit  \
# year
# 2021            4.787000e+02          3799.2  1.048459e+07      511304.276
# 2022            4.723135e+07             NaN  2.198110e+07     1405274.134
#
# Payment Method  easypay_voucher  financesettlement  jazzvoucher   jazzwallet  \
# year
# 2021               2.891499e+07             2059.9   178238.195   617706.306
# 2022               1.257738e+07                NaN  5303058.014  1880888.262
#
# Payment Method   mcblite
# year
# 2021            163340.8
# 2022                 NaN

# %% [markdown]
# -In highest order, the trendlines show that Bankalfalah, Easypay_Voucher, Payaxis and Jazzvoucher are the best performing
#  payment methods in 2022.
#
# -Bankalfalah which was performing the poorest in 2021 gained sudden popularity against other payment methods by big margin.
#
# -The Easypay_voucher seem to be confortable at its positions as it is observed that usage is comparable the same for both yeas.
#
# -The stangnancy of easypay_voucher didn't affect its performance.
#
# -Although the Mcblite, cashatdoorstep and financesettlement payment methods were active in 2021, their usage has not been
#  esterblsihed by users in 2022. This could mean that it is either outdated or out of popularity.

# %%
#Compare Revenue and 3 variable to unerstand trends
plt.figure(figsize=(25,10))
plt.xticks(fontsize=11)
plt.yticks(fontsize=20)
plt.xlabel('Category', fontsize=25)
plt.ylabel('Revenue',  fontsize=25)
sns.lineplot(x="Category", y="Revenue", data=df, hue='year')
plt.title('CATEGORY/REVENUE TREND ANALYSIS', fontsize=30);

# %% [markdown]
# -An overall revenue increase in 2022 conpare to 2021.
#
# -Highest revenue record is observed within products of electric funtionality.
#
# -Mobile & Tablets, Men fashoin, Entertainment, computing and appliances generated the most revenue in both years.
#
# -The book product appears to be the least performing in term of revenue generation.
#
# -Entertainment at some point had slight lesser performance in 2022 but bounced back.

# %%
#Correlation Evaluation
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True);

# %% [markdown]
# COMMENTS:
#
# From the heatmap, we can see the variables that have negative and positive relationships.
#
# Revenue and Unity_price have 94% correlation. This ground truths earlier observations that the price of goods are just right for the business and good revenue is realised.
#
# Another good relationship exist between the Quarter and month, item Id and year. This interprets to means that the products purchased by customers in a year goes well with the business expectations by 84%.

# %% [markdown]
# # CONCLUSION
#
# The users are more inclined towards Mobile & Tablets, Men’s fashion, Appliances, and Superstore products with books and school products as the least desired. The most qty ordered and highest revenue is observed in December and April. Col and Easypay are the most preferred in terms of product order and revenue generation respectively. Beebe, Glines, and Jesse are the top 3 performing customers.
#
# Although the male gender seems to make the most purchase the females turn in greater revenue for Sterling e-commerce. It was noted that more orders were placed in the year 2022, and this complements the surge in the use of payment methods in the same year.
#
# To boast unpopular payment method usability, increase the order of the least desired product category, and maximize revenue,  it is recommended that the campaign be built around the payment methods, Books, and schools products. Using the discount implementation strategy, new customers could be won over while old customers could make more purchases.
#
# Moving forward, it is advised that the purchase table including cost variables be made available for effective profit calculation. This will provide insight into which product performs better than the other.

# %%
pip install pandas_profiling

# %%
from pandas_profiling import ProfileReport
